# %% [markdown]
# # Results of Leaning rate ruBert-tiny2

# %% [markdown]
# Загружаем библиотеки

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# 2936 Статей 2024 года +  2000 статей из https://github.com/RossiyaSegodnya/ria_news_dataset<br><br>
# Chunk_size = 256<br>
# batc size = 16<br>
# Token Masking = 15%<br><br>
#
# optimizer = 5e-5<br>
# >>> Epoch 0: Perplexity: 25.344175798521757<br>
# >>> Epoch 1: Perplexity: 23.639866414623214<br>
# >>> Epoch 2: Perplexity: 22.745400418665724<br>
# >>> Epoch 3: Perplexity: 22.235403311931943<br>
# >>> Epoch 4: Perplexity: 22.01847757085492<br><br>
#
# optimizer = 1e-4<br>
# >>> Epoch 0: Perplexity: 24.07491587915554<br>
# >>> Epoch 1: Perplexity: 22.169864283419805<br>
# >>> Epoch 2: Perplexity: 20.968802662007572<br>
# >>> Epoch 3: Perplexity: 20.283259773810773<br>
# >>> Epoch 4: Perplexity: 20.014415889474236<br>
#
# optimizer = 5e-4<br>
# >>> Epoch 0: Perplexity: 32.57766212108949<br>
# >>> Epoch 1: Perplexity: 27.857810892264936<br>
# >>> Epoch 2: Perplexity: 24.552484605308898<br>
# >>> Epoch 3: Perplexity: 22.389274333841307<br>
# >>> Epoch 4: Perplexity: 21.342648134568197<br>
#
# optimizer = 1e-3<br>
# >>> Epoch 0: Perplexity: 53.02048400094664<br>
# >>> Epoch 1: Perplexity: 41.08786349164676<br>
# >>> Epoch 2: Perplexity: 33.60121173882428<br>
# >>> Epoch 3: Perplexity: 28.851600010427187<br>
# >>> Epoch 4: Perplexity: 26.266593185627183<br><br>
#
# optimizer = 2e-4<br>
# >>> Epoch 0: Perplexity: 25.694742325863604<br>
# >>> Epoch 1: Perplexity: 23.146322855097658<br>
# >>> Epoch 2: Perplexity: 21.44864408078294<br>
# >>> Epoch 3: Perplexity: 20.528689718437466<br>
# >>> Epoch 4: Perplexity: 20.040477373880396<br><br>

# %%
fig, ax = plt.subplots()
adam = [5e-5, 1e-4, 2e-4, 5e-4, 1e-3]
lr = [3.3256982276668374, 4.060499989681304, 5.654264951983208, 11.235013986521292, 26.266593185627183]
perp = [22.01847757085492, 20.014415889474236, 20.040477373880396, 21.342648134568197, 26.266593185627183]

ax.semilogx(adam, lr, label="Learning rate")
ax.semilogx(adam, perp, label="Perplexity")

ax.legend()
