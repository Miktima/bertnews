# %% [markdown]
# # F-SCORE Results
#
# ## Uncorrect masking  - masking words not tokens

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# 249 Sentences<br><br>
# Yandex Speller<br>
# Precision:  0.7992700729927007<br>
# Recall:  0.8795180722891566<br>
# F-measure:  0.8374760994263862<br><br>
#
# ai-forever/ruBert-base (128 chunk)<br>
# treshold = 0.00001<br>
# Precision:  0.30548302872062666<br>
# Recall:  0.46987951807228917<br>
# F-measure:  0.37025316455696206<br><br>
#
# ai-forever/ruBert-base (256 chunk)<br>
# treshold = 0.00001<br>
# Precision:  0.32222222222222224<br>
# Recall:  0.46586345381526106<br>
# F-measure:  0.380952380952381<br><br>
# treshold = 0.00005<br>
# Precision:  0.2595281306715064<br>
# Recall:  0.5742971887550201<br>
# F-measure:  0.3575<br><br>
# treshold = 0.000005<br>
# Precision:  0.3543046357615894<br>
# Recall:  0.42971887550200805<br>
# F-measure:  0.3883847549909256<br><br>
# treshold = 0.000001<br>
# Precision:  0.44886363636363635<br>
# Recall:  0.3172690763052209<br>
# F-measure:  0.3717647058823529<br><br>
# treshold = 0.000003<br>
# Precision:  0.3798449612403101<br>
# Recall:  0.39357429718875503<br>
# F-measure:  0.3865877712031558<br>

# %%
fig, ax = plt.subplots()
treshold = [0.000001, 0.000003, 0.000005, 0.00001, 0.00005]
prec = [0.44886363636363635, 0.3798449612403101, 0.3543046357615894, 0.32222222222222224, 0.2595281306715064]
recall = [0.3172690763052209, 0.39357429718875503, 0.42971887550200805, 0.46586345381526106, 0.5742971887550201]
f1 = [0.3717647058823529, 0.3865877712031558, 0.3883847549909256, 0.380952380952381, 0.3575]
ax.semilogx(treshold, prec, label="Precision")
ax.semilogx(treshold, recall, label="Recall")
ax.semilogx(treshold, f1, label="F-score")
ax.legend()

# %% [markdown]
# ## ai-forever/ruRoberta-large (267 sentences)<br>
# treshold = 5.0e-6<br>
# Precision:  0.0791599353796446<br>
# Recall:  0.9107806691449815<br>
# F-measure:  0.1456599286563615<br><br>
#
# treshold = 1.0e-5<br>
# Precision:  0.07508325764456554<br>
# Recall:  0.9219330855018587<br>
# F-measure:  0.13885778275475924<br><br>
#
# treshold = 1.0e-4<br>
# Precision:  0.06435520079820405<br>
# Recall:  0.9591078066914498<br>
# F-measure:  0.120617110799439<br><br>
#
# treshold = 1.0e-6<br>
# Precision:  0.08628884826325411<br>
# Recall:  0.8773234200743495<br>
# F-measure:  0.15712383488681758<br><br>
#
# treshold = 1.0e-7<br>
# Precision:  0.09215328467153285<br>
# Recall:  0.7509293680297398<br>
# F-measure:  0.16416091019910603<br><br>
#
# treshold = 1.0e-8<br>
# Precision:  0.09578270192994996<br>
# Recall:  0.49814126394052044<br>
# F-measure:  0.1606714628297362<br><br>
#
# treshold = 1.0e-9<br>
# Precision:  0.10394736842105264<br>
# Recall:  0.2936802973977695<br>
# F-measure:  0.15354713313896987<br><br>

# %%
fig, ax = plt.subplots()
treshold = [1.0e-9, 1.0e-8, 1.0e-7, 1.0e-6, 5.0e-6, 1.0e-5, 1.0e-4]
prec = [0.10394736842105264, 0.09578270192994996, 0.09215328467153285, 0.08628884826325411, 0.0791599353796446, 0.07508325764456554, 0.06435520079820405]
recall = [0.2936802973977695, 0.49814126394052044, 0.7509293680297398, 0.8773234200743495, 0.9107806691449815, 0.9219330855018587, 0.9591078066914498]
f1 = [0.15354713313896987, 0.1606714628297362, 0.16416091019910603, 0.15712383488681758, 0.1456599286563615, 0.13885778275475924, 0.120617110799439]
ax.semilogx(treshold, prec, label="Precision")
ax.semilogx(treshold, recall, label="Recall")
ax.semilogx(treshold, f1, label="F-score")
ax.legend()

# %% [markdown]
# ## cointegrated/rubert-tiny2 (267 sentences)<br>
# treshold = 1.0e-5<br>
# Precision:  0.2996031746031746<br>
# Recall:  0.5613382899628253<br>
# F-measure:  0.3906856403622251<br><br>
#
# treshold = 5.0e-5<br>
# Precision:  0.2699724517906336<br>
# Recall:  0.7286245353159851<br>
# F-measure:  0.3939698492462312<br><br>
#
# treshold = 1.0e-4<br>
# Precision:  0.24733727810650888<br>
# Recall:  0.7769516728624535<br>
# F-measure:  0.3752244165170556<br><br>
#
# treshold = 1.0e-6<br>
# Precision:  0.36099585062240663<br>
# Recall:  0.32342007434944237<br>
# F-measure:  0.3411764705882353<br><br>
#
# treshold = 5.0e-6<br>
# Precision:  0.3261904761904762<br>
# Recall:  0.5092936802973977<br>
# F-measure:  0.397677793904209<br>

# %%
fig, ax = plt.subplots()
treshold = [1.0e-6, 5.0e-6, 1.0e-5, 5.0e-5, 1.0e-4]
prec = [0.36099585062240663, 0.3261904761904762, 0.2996031746031746, 0.2699724517906336, 0.24733727810650888]
recall = [0.32342007434944237, 0.5092936802973977, 0.5613382899628253, 0.7286245353159851, 0.7769516728624535]
f1 = [0.3411764705882353, 0.397677793904209, 0.3906856403622251, 0.3939698492462312, 0.3752244165170556]
ax.semilogx(treshold, prec, label="Precision")
ax.semilogx(treshold, recall, label="Recall")
ax.semilogx(treshold, f1, label="F-score")
ax.legend()

# %% [markdown]
# Fine-tune:<br>
# 2936 Статей 2024 года +  2000 статей из https://github.com/RossiyaSegodnya/ria_news_dataset<br>
# +<br>
# 2936 Статей 2024 года (тех же) +  5000 статей из https://github.com/RossiyaSegodnya/ria_news_dataset<br>
# 308 error sentences<br>
# treshold = 5.0e-6<br>
# Precision:  0.3008474576271186<br>
# Recall:  0.45806451612903226<br>
# F-measure:  0.3631713554987212<br><br>
#
# treshold = 1.0e-5<br>
# Precision: 0.28295254833040423<br>
# Recall: 0.5193548387096775<br>
# F-measure: 0.36632536973833907<br><br>
#
# treshold = 5.0e-5<br>
# Precision:  0.26<br>
# Recall:  0.7129032258064516<br>
# F-measure:  0.3810344827586207<br><br>
#
# treshold = 1.0e-4<br>
# Precision:  0.24667349027635618<br>
# Recall:  0.7774193548387097<br>
# F-measure:  0.37451437451437447<br>

# %%
fig, ax = plt.subplots()
treshold = [5e-6, 1e-5, 5e-5, 1e-4]
prec = [0.3008474576271186, 0.28295254833040423, 0.26, 0.24667349027635618]
recall = [0.45806451612903226, 0.5193548387096775, 0.7129032258064516, 0.7774193548387097]
f1 = [0.3631713554987212, 0.36632536973833907, 0.3810344827586207, 0.37451437451437447]
ax.semilogx(treshold, prec, label="Precision")
ax.semilogx(treshold, recall, label="Recall")
ax.semilogx(treshold, f1, label="F-score")
ax.legend()
